# %%
#Libraries
import os
import json
from PIL import Image
import time
import google.generativeai as genai
# API key config
with open("config.json", "r") as f:
    config = json.load(f)
    
genai.configure(api_key=config['gemini_api_key'])

# %%
# Listing available models
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
# image_path = input("input image location: ")
image_path = "/home/copper_turtle/code/gemini_practice/images/fridge.jpg"
if not os.path.isfile(image_path):
    raise SystemExit("invalid Path, Exiting ... ")

img = Image.open(image_path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=424x291>

# %%
model = genai.GenerativeModel("gemini-pro-vision")
while True:
    prompt = input("Question: ")
    if prompt.lower() not in ['exit', 'bye', 'quit']:
        response = model.generate_content([prompt, img])
        print('')
        print(response.text)
        print("-" * 100)
    else:
        print('Quitting ... ')
        time.sleep(2)
        print('stopped')
        break
# Out:
#  The image shows the inside of a refrigerator. On the top shelf, there are bottles of ketchup, mustard, salad dressing, and a jug of milk. On the middle shelf, there are some containers of leftovers, a package of sliced ham, and a box of eggs. On the bottom shelf, there are some fruits and vegetables, including apples, oranges, grapes, and tomatoes. There is also a container of yogurt and a carton of cottage cheese. The door of the refrigerator has a container of eggs, a box of baking soda, and a bottle of juice.
# ----------------------------------------------------------------------------------------------------
#
#  * A salad with lettuce, tomatoes, onions, and peppers
# * A sandwich with ham, cheese, and lettuce
# * Scrambled eggs with tomatoes and onions
# * A fruit salad with grapes, oranges, and apples
# * A smoothie with milk, yogurt, and fruit
# ----------------------------------------------------------------------------------------------------
#
#  The carb count of the recipes in the image would be 19g.
# ----------------------------------------------------------------------------------------------------
# Quitting ...
